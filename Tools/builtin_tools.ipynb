# %%
# !pip install langchain langchain_community pydantic duckduckgo-search langchain_experimental langchain-core ddgs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.9 MB/s eta 0:00:00
# ...

# %%
#duck duck go search
from langchain_community.tools import DuckDuckGoSearchRun

search_tool= DuckDuckGoSearchRun()
result=search_tool.invoke("how many kids kohli has?")
print(result)
# Out:
# 4 days ago -His interest in sports franchises continued as he became a co-owner of the UAE Royals in the International Premier Tennis League and the Bengaluru Yodhas, a Pro Wrestling League franchise. In 2016, Kohli helped launch Stepathlon Kids, an initiative aiming to encourage children to adopt healthy lifestyles. 2 weeks ago -She is the ambassador for brands ... and animal rights. Sharma is married to cricketer Virat Kohli with whom she hastwo children.... August 20, 2025 -Virat Kohli hastwo kids, a daughter named Vamika and a son named Akaay. July 3, 2025 -However, off the field, Kohli has always wanted to have a low-key personal life. He got married to mainstream Bollywood actress Anushka Sharma in 2017 and is a father totwo kids. June 18, 2025 -Virat Kohli and Anushka Sharma are proud parents oftwo children—daughter Vamika and son Akaay. The couple values privacy and has kept their kids away from the public spotlight.

# %%
#shell tool
from langchain_community.tools import ShellTool
shell_tool=ShellTool()
result=shell_tool.invoke("whoami")
# Out:
# Executing command:
#  whoami

# %%
#https://docs.langchain.com/docs/integrations/
#see more tools
